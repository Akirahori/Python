# %% [markdown]
# # Noções básicas com dados OHLC

# %% [markdown]
# * O - Open
# * H = High
# * L - Low
# * C - Close

# %%
## YFINANCE
import numpy as np 
import pandas as pd 
import yfinance as yf 
import pandas_datareader as pdr

# %%
msft = yf.download('MSFT', start= '2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
msft.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-03 00:00:00-05:00  243.080002  245.750000  237.399994  239.580002
# 2023-01-04 00:00:00-05:00  232.279999  232.869995  225.960007  229.100006
# 2023-01-05 00:00:00-05:00  227.199997  227.550003  221.759995  222.309998
# 2023-01-06 00:00:00-05:00  223.000000  225.759995  219.350006  224.929993
# 2023-01-09 00:00:00-05:00  226.449997  231.240005  226.410004  227.119995
#
#                             Adj Close    Volume
# Date
# 2023-01-03 00:00:00-05:00  238.981430  25740000
# 2023-01-04 00:00:00-05:00  228.527618  50623400
# 2023-01-05 00:00:00-05:00  221.754562  39585600
# 2023-01-06 00:00:00-05:00  224.368011  43597700
# 2023-01-09 00:00:00-05:00  226.552551  27369800

# %%
msft_ohlc= msft[['Open', 'High', 'Low', 'Close'  ]]

# %%
msft_ohlc.head()
# Out:
#                                  Open        High         Low       Close
# Date
# 2023-01-03 00:00:00-05:00  243.080002  245.750000  237.399994  239.580002
# 2023-01-04 00:00:00-05:00  232.279999  232.869995  225.960007  229.100006
# 2023-01-05 00:00:00-05:00  227.199997  227.550003  221.759995  222.309998
# 2023-01-06 00:00:00-05:00  223.000000  225.759995  219.350006  224.929993
# 2023-01-09 00:00:00-05:00  226.449997  231.240005  226.410004  227.119995

# %%
msft_ohlc.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
abev = yf.download('ABEV3.SA', start= '2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
abev.head()
# Out:
#                             Open   High    Low  Close  Adj Close    Volume
# Date
# 2023-01-02 00:00:00-03:00  14.40  14.45  14.02  14.19      14.19  14995900
# 2023-01-03 00:00:00-03:00  14.16  14.39  14.11  14.17      14.17  36363800
# 2023-01-04 00:00:00-03:00  14.28  14.47  14.08  14.25      14.25  23791800
# 2023-01-05 00:00:00-03:00  14.27  14.41  14.14  14.29      14.29  31031500
# 2023-01-06 00:00:00-03:00  14.30  14.36  14.16  14.32      14.32  20889800

# %%
abev_ohlc= abev[['Open', 'High', 'Low', 'Close'  ]]

# %%
abev_ohlc
# Out:
#                             Open   High    Low  Close
# Date
# 2023-01-02 00:00:00-03:00  14.40  14.45  14.02  14.19
# 2023-01-03 00:00:00-03:00  14.16  14.39  14.11  14.17
# 2023-01-04 00:00:00-03:00  14.28  14.47  14.08  14.25
# 2023-01-05 00:00:00-03:00  14.27  14.41  14.14  14.29
# 2023-01-06 00:00:00-03:00  14.30  14.36  14.16  14.32
# 2023-01-09 00:00:00-03:00  14.29  14.47  14.27  14.40
# 2023-01-10 00:00:00-03:00  14.26  14.60  14.25  14.54
# 2023-01-11 00:00:00-03:00  14.51  14.79  13.95  14.29
# 2023-01-12 00:00:00-03:00  13.80  14.17  13.66  14.10
# 2023-01-13 00:00:00-03:00  14.00  14.05  13.77  13.88
# 2023-01-16 00:00:00-03:00  13.72  13.74  13.18  13.20
# 2023-01-17 00:00:00-03:00  13.30  13.95  13.20  13.86
# 2023-01-18 00:00:00-03:00  13.93  14.06  13.73  13.78
# 2023-01-19 00:00:00-03:00  13.67  13.85  13.55  13.64
# 2023-01-20 00:00:00-03:00  13.55  13.64  13.37  13.53
# 2023-01-23 00:00:00-03:00  13.56  13.68  13.36  13.42
# ...

# %%
abev_ohlc.to_csv('ABEV3_OHLC.csv', sep=';', decimal= ',')#Salvando arquivo em CSV

# %%
dados = pd.read_csv('ABEV3_OHLC.csv', sep=';', decimal= ',')#Importando o documento da minha rede.

# %%
dados.dtypes
# Out:
# Date      object
# Open     float64
# High     float64
# Low      float64
# Close    float64
# dtype: object

# %%
dados['Date'] = pd.to_datetime(dados['Date'])

# %%
dados.index = dados.Date
dados
# Out:
#                                                Date   Open   High    Low  \
# Date
# 2023-01-02 00:00:00-03:00 2023-01-02 00:00:00-03:00  14.40  14.45  14.02
# 2023-01-03 00:00:00-03:00 2023-01-03 00:00:00-03:00  14.16  14.39  14.11
# 2023-01-04 00:00:00-03:00 2023-01-04 00:00:00-03:00  14.28  14.47  14.08
# 2023-01-05 00:00:00-03:00 2023-01-05 00:00:00-03:00  14.27  14.41  14.14
# 2023-01-06 00:00:00-03:00 2023-01-06 00:00:00-03:00  14.30  14.36  14.16
# 2023-01-09 00:00:00-03:00 2023-01-09 00:00:00-03:00  14.29  14.47  14.27
# 2023-01-10 00:00:00-03:00 2023-01-10 00:00:00-03:00  14.26  14.60  14.25
# 2023-01-11 00:00:00-03:00 2023-01-11 00:00:00-03:00  14.51  14.79  13.95
# 2023-01-12 00:00:00-03:00 2023-01-12 00:00:00-03:00  13.80  14.17  13.66
# 2023-01-13 00:00:00-03:00 2023-01-13 00:00:00-03:00  14.00  14.05  13.77
# 2023-01-16 00:00:00-03:00 2023-01-16 00:00:00-03:00  13.72  13.74  13.18
# 2023-01-17 00:00:00-03:00 2023-01-17 00:00:00-03:00  13.30  13.95  13.20
# ...

# %%
dados.drop('Date', axis= 1, inplace= True)#Removendo a coluna date que estava em duplicidade

# %%
dados
# Out:
#                             Open   High    Low  Close
# Date
# 2023-01-02 00:00:00-03:00  14.40  14.45  14.02  14.19
# 2023-01-03 00:00:00-03:00  14.16  14.39  14.11  14.17
# 2023-01-04 00:00:00-03:00  14.28  14.47  14.08  14.25
# 2023-01-05 00:00:00-03:00  14.27  14.41  14.14  14.29
# 2023-01-06 00:00:00-03:00  14.30  14.36  14.16  14.32
# 2023-01-09 00:00:00-03:00  14.29  14.47  14.27  14.40
# 2023-01-10 00:00:00-03:00  14.26  14.60  14.25  14.54
# 2023-01-11 00:00:00-03:00  14.51  14.79  13.95  14.29
# 2023-01-12 00:00:00-03:00  13.80  14.17  13.66  14.10
# 2023-01-13 00:00:00-03:00  14.00  14.05  13.77  13.88
# 2023-01-16 00:00:00-03:00  13.72  13.74  13.18  13.20
# 2023-01-17 00:00:00-03:00  13.30  13.95  13.20  13.86
# 2023-01-18 00:00:00-03:00  13.93  14.06  13.73  13.78
# 2023-01-19 00:00:00-03:00  13.67  13.85  13.55  13.64
# 2023-01-20 00:00:00-03:00  13.55  13.64  13.37  13.53
# 2023-01-23 00:00:00-03:00  13.56  13.68  13.36  13.42
# ...

# %%
import pandas_datareader as pdr

# %%
import pandas_datareader.data as web

import pandas as pd

import datetime as dt

# %%
df = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-d1636866488d> in <module>
# ----> 1 df = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     368
#     369     if data_source == "yahoo":
# --> 370         return YahooDailyReader(
#     371             symbols=name,
#     372             start=start,
#
# ~\anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
# ...

# %% [markdown]
# # Conceito de normalização

# %%
lista = ['WEGE.SA', 'MGLU3.SA', 'EMBRE3.SA', '^GSPC', '^BVSP', 'HCTR11.SA', 'SMAL11.SA']

# %%
data = pd.DataFrame

# %%
for i in lista:
    data[i] = pdr.data.get_data_yahoo(i, start = '2023-01-01').Close
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ea1dd242224b> in <module>
#       1 for i in lista:
# ----> 2     data[i] = pdr.data.get_data_yahoo(i, start = '2023-01-01').Close
#
# ~\anaconda3\lib\site-packages\pandas_datareader\data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# ~\anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ...
