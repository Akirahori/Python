# %% [markdown]
# PIB - qual a relação das receitas, mkt share com o PIB
#
# Selic - aumenta a taxa de desconto dos valuations
#
#
# IPCA - a empresa consegue repassar os futuros aumentos de custos e preços

# %%
# !PIp install quandl

# %%
import quandl
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# C:\Users\akira\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
quandl.ApiConfig.api_key = 'C4Z4Z9dzgAD3dFooEXsG'

# %%
cesta_basica_sp = quandl.get("BCB/7481", start_date = '2015-01-01')

# %%
cesta_basica_sp.head()
# Out:
#              Value
# Date
# 2015-01-31  337.57
# 2015-02-28  341.72
# 2015-03-31  343.22
# 2015-04-30  348.36
# 2015-05-31  355.92

# %%
plt.figure(figsize=(8,5))
plt.plot(cesta_basica_sp);

# %% [markdown]
# # 2.PIB - Produto interno bruto(USD)

# %% [markdown]
# PIB é a soma dde todos os bens e serviços produzidos em território nacional

# %%
pib = quandl.get("ODA/BRA_NGDPD", start_date = '2010-01-01')

# %%
pib.head()
# Out:
#               Value
# Date
# 2010-12-31  2207.62
# 2011-12-31  2613.99
# 2012-12-31  2464.40
# 2013-12-31  2471.56
# 2014-12-31  2456.17

# %%
plt.figure(figsize=(8,5))
plt.plot(pib);

# %%
pib.tail()
# Out:
#               Value
# Date
# 2020-12-31  2062.50
# 2021-12-31  2156.50
# 2022-12-31  2255.58
# 2023-12-31  2359.53
# 2024-12-31  2468.22

# %% [markdown]
# # 3. SELIC

# %% [markdown]
# Selic é a taxa básica de juros da economia definida pelo COPOM

# %%
selic = quandl.get("BCB/432", start_date = '2010-01-01')

# %%
selic.head()
# Out:
#             Value
# Date
# 2010-01-01   8.75
# 2010-01-02   8.75
# 2010-01-03   8.75
# 2010-01-04   8.75
# 2010-01-05   8.75

# %%
plt.figure(figsize=(8,8))
plt.plot(selic);

# %% [markdown]
# # 4.IPCA(Índice de preços ao consumidor amplo)

# %% [markdown]
# - Mede o poder de compra da população e acompanha o nível de preços de diversos segmentos de consumo.

# %%
ipca = quandl.get("BCB/13522", start_date = "2010-01-01")

# %%
ipca.head()
# Out:
#             Value
# Date
# 2010-01-31   4.59
# 2010-02-28   4.83
# 2010-03-31   5.17
# 2010-04-30   5.26
# 2010-05-31   5.22

# %%
plt.figure(figsize=(8,8))
plt.title('IPCA')
plt.plot(ipca);

# %%
IGPM = quandl.get("BCB/189", start_date = '2010-01-01')

# %%
IGPM.head()
# Out:
#             Value
# Date
# 2010-01-31   0.63
# 2010-02-28   1.18
# 2010-03-31   0.94
# 2010-04-30   0.77
# 2010-05-31   1.19

# %%
plt.figure(figsize=(8,8))
plt.plot(IGPM);

# %% [markdown]
# # DÓLAR

# %% [markdown]
# - Dolar moeda estrangeira de reserva reflete o humor investidor estrangeiro em relação ao risco do país e também o saldo da
# balança comercial

# %%
dolar = quandl.get("BCB/10813", start_date = '2010-01-01')

# %%
dolar.head()
# Out:
#              Value
# Date
# 2010-01-04  1.7232
# 2010-01-05  1.7219
# 2010-01-06  1.7329
# 2010-01-07  1.7405
# 2010-01-08  1.7382

# %%
plt.figure(figsize=(8,8))
plt.title('Variação do Dólar')
plt.plot(dolar);

# %% [markdown]
# # 6. Cruzar análises de séries temporais em um gráfico com eixo secundário

# %%
cesta_basica_mg = quandl.get("BCB/7481", start_date = '2015-01-01')

# %%
cesta_basica_mg.head()
# Out:
#              Value
# Date
# 2015-01-31  337.57
# 2015-02-28  341.72
# 2015-03-31  343.22
# 2015-04-30  348.36
# 2015-05-31  355.92

# %%
fig, ax1 = plt.subplots(figsize=(9,9))
color ='tab:red'
ax1.set_xlabel('Data')
ax1.set_ylabel('SP', color=color)
ax1.plot(cesta_basica_sp, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color2 = 'tab:blue'
ax2.set_ylabel('MG', color=color2)
ax2.plot(cesta_basica_mg, color=color2)
ax2.tick_params(axis='y',labelcolor=color2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
